# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
url = 'https://movie.naver.com/movie/bi/mi/point.naver?code=187320#'
res = req.get(url)
res
# Out:
# <Response [200]>

# %%
soup = bs(res.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>씽2게더 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 씽2게더" property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="씽2게더" property="me2:category2"/>
# <meta content="씽2게더" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/point.naver?code=187320" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20211231_136/1640927037740RqKuo_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="대국민 오디션 이후 각자의 자리에서 꿈을 이루고 있는 버스터 문(매튜 맥커너히)과 크루들에게레드 쇼..." property="og:description"/>
# ...

# %%
reply = []
for i in range(10):
    sel = 'span#_filtered_ment_'+str(i)
    txt = soup.select_one(sel)
    reply.append(txt)

# %%
reply
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# # 데이터 접근이 불가능한 이유는 화면에는 보이지만 실제 데이터는 iframe 태그를 통해 다른 주소에 존재하기 때문이다. 따라서, 실제 데이터가 존재하는 주소로 찾아가 주어야 한다.

# %%
url = 'https://movie.naver.com//movie/bi/mi/pointWriteFormList.naver?code=187320&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'
res = req.get(url)
res
# Out:
# <Response [200]>

# %%
soup = bs(res.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20220110163618" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_tablet.css?20220110163618" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20220110163618" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20220110163618" type="text/javascript"></script>
# </head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="187320"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# ...

# %% [markdown]
# # 1. 불필요한 개행문자(이스케이프코드) 삭제하는 방법 : .strip()

# %% [markdown]
# # 2. 불필요한 부분 제거 하는 방법
# - 불필요한 부분 수집 : viewer = soup.select('span.ico_viewer')
# - 추출 : .extract()
# - ex) for i in viewer: i.extract()

# %%
reply = []
for i in range(10):
    sel = 'span#_filtered_ment_'+str(i)
    txt = soup.select_one(sel).text.strip()
    reply.append(txt)
reply
# Out:
# ['가슴이 웅장해진다 미스터문ㅜ 성공했다',
#  '아침 조조로 봤는데 이번편도 재밌네요 노래도 좋았다',
#  '생각보다 너무 재밌게 봤네요. 개인적으로 조니 음악과 마지막 곡이 제일 좋았어요. 의외로 감동포인트도 있네요. 눈물 찔끔ㅠ 한 번 더 보고싶어요.',
#  '개인적으로 1편보다 더 좋았음.. 노래도 영화에 어울리게 선곡 잘한 것 같아요!',
#  '전편보다 훨씬 발전한 2편. 노래 진짜 좋음.',
#  '느슨한 영화계에 긴장감을 주는 영화',
#  '시간가는 줄 모르게 관람했어요.',
#  '내용 노래 감동 최고네요~',
#  '믿고 듣는 씽! 노래가 너무 좋아요',
#  '최고예요!!!! 진부하지 않아요ㅠㅠㅠ']

# %%
for j in range(1,10):
    res = req.get("https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=187320&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page="+str(j))
    soup = bs(res.text,"lxml")
    viewer = soup.select("span.ico_viewer")
    for i in viewer :
        i.extract()
    spo = soup.select("span.text_spo._text_spo")
    for i in spo:
        i.extract()
    review = soup.select("div.score_reple > p")
    for i in review :
        print(i.text.strip())
# Out:
# 가슴이 웅장해진다 미스터문ㅜ 성공했다
# 아침 조조로 봤는데 이번편도 재밌네요 노래도 좋았다
# 생각보다 너무 재밌게 봤네요. 개인적으로 조니 음악과 마지막 곡이 제일 좋았어요. 의외로 감동포인트도 있네요. 눈물 찔끔ㅠ 한 번 더 보고싶어요.
# 개인적으로 1편보다 더 좋았음.. 노래도 영화에 어울리게 선곡 잘한 것 같아요!
# 전편보다 훨씬 발전한 2편. 노래 진짜 좋음.
# 느슨한 영화계에 긴장감을 주는 영화
# 시간가는 줄 모르게 관람했어요.
# 내용 노래 감동 최고네요~
# 믿고 듣는 씽! 노래가 너무 좋아요
# 최고예요!!!! 진부하지 않아요ㅠㅠㅠ
# 아들과 너무 재미있게 봤습니다
# 씽1보다 재밌었어요3도 나왔으면 좋겠어요
# 음악 미쳤고, 딱 그 곳에 잘 맞고, 마지막엔 감동 까지, 영화 끝나고 박수치게 됨. 저절로,
# 진짜 명작이에요 ㅋㅋㅋ 애니 보면서 오랜만에 감동을 느껴봤어요 ~
# 문버스터 고생했다..ㅠㅠㅠㅠ 너무너무너무 재밌게봤습니다
# 뻔한 이야기지만, 남녀노소 할 것 없이 즐거운 시간을 시간을 선사해주는 흥겨운 애니메이션, 왠지 모르게 뭉클한 것은 왜일까
# 영화 보는 내내 즐겁다~♬♬
# 너무 신나게 본 영화에요! 노래가 아직도 귀에서 맴도네요! 소리 빵빵한 상영관 추천합니다!
# 일루미네이션 최고의 음악영화
# 어린이 영화여서 기대 안하고 봤는데 노래가 너무 좋아서 재미있게 봄
# 아침 조조로 봤는데 기대보다 재밌었어요 OST도 훌륭하고 개인적으로 씽1보다 더 재밌는 것 같아요
# 무조건 봐야하는 영화..
# 너무 재밌고요~ 노래 다양해서 보는데 지루하지 않았어요 최고에용!!
# 1편처럼 신나는 노래들의 향연
# 노래 너무 신나고 재미있어요
# 노래가 너무 좋았어요. 편안하고 재미있게 잘 봤습니다.
# 음악좋고 캐릭터들도 귀엽네요.
# 입이 떡 벌어지는 공연 연출에 감탄했습니다. 새해 첫 영화로 최고의 선택이었네요.
# 멋있는 무대와 신나는 노래로 즐기는 두시간:)
# 대박 존잼 노래겁나좋아
# 1편보다 더 좋았어요~
# ...
